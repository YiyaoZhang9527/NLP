# %%
import numpy as np
from IPython.display import IFrame,Image

# %%
questions = {1:'本课程是线上课程还是线下课程',2:'课程有助教吗',3:'学习周期是多久啊',4:'如果不满意可以退款吗?', 5:'老师都是什么背景啊?',6:'课程会有考试吗',7:'我只有编程基础,可以报名吗',8:'课程有实操吗',9:'课程为什么贵',10:'课程学完了能做什么?'}
answer = {1:'回答:线上课程为主',2:'每门课程都配备专业助教',3:'通常来讲在3-4个月不等',4:'前两周提供无条件退款',5:'绝大部分都是全美前10学校的博士',6:'有的。一般包括期中和期末',7:'回答:对于初级的项目班只要求编程基础',8:'大部分都是实操,动手能力是最重要的',9:'跟别的知识付费不一样,我们会提供很多教学服务,辅助完成学员做完所有的项目',9:'可以找相关岗位的工作问题不大'}

# %%
def knowledge_base(**key):
    questions = {1:'本课程是线上课程还是线下课程',2:'课程有助教吗',3:'学习周期是多久啊',4:'如果不满意可以退款吗?', 5:'老师都是什么背景啊?',6:'课程会有考试吗',7:'我只有编程基础,可以报名吗',8:'课程有实操吗',9:'课程为什么贵',10:'课程学完了能做什么?'}
    answer = {1:'回答:线上课程为主',2:'每门课程都配备专业助教',3:'通常来讲在3-4个月不等',4:'前两周提供无条件退款',5:'绝大部分都是全美前10学校的博士',6:'有的。一般包括期中和期末',7:'回答:对于初级的项目班只要求编程基础',8:'大部分都是实操,动手能力是最重要的',9:'跟别的知识付费不一样,我们会提供很多教学服务,辅助完成学员做完所有的项目',9:'可以找相关岗位的工作问题不大'}
    return key

# %%
knowledge_base(answer=answer)
# Out:
# {'answer': {1: '回答:线上课程为主',
#   2: '每门课程都配备专业助教',
#   3: '通常来讲在3-4个月不等',
#   4: '前两周提供无条件退款',
#   5: '绝大部分都是全美前10学校的博士',
#   6: '有的。一般包括期中和期末',
#   7: '回答:对于初级的项目班只要求编程基础',
#   8: '大部分都是实操,动手能力是最重要的',
#   9: '可以找相关岗位的工作问题不大'}}

# %%
from IPython.display import display, Image
img_path1 = "/Users/manmanzhang/Library/Mobile Documents/com~apple~CloudDocs/MyProject/InferenceSystem/src/I5_algorithm/NLP训练营笔记/图片/78E05D72-F695-439D-8763-FBCAE811F877.png"
display(Image(filename=img_path1))

# %%
img_path2 = "/Users/manmanzhang/Library/Mobile Documents/com~apple~CloudDocs/MyProject/InferenceSystem/src/I5_algorithm/NLP训练营笔记/图片/721DBA2E-36FA-40A6-B5CB-51F4F42EDDCE.png"
display(Image(filename=img_path2))

# %% [markdown]
# # 分词工具

# %%
img_path3 = "/Users/manmanzhang/Library/Mobile Documents/com~apple~CloudDocs/MyProject/InferenceSystem/src/I5_algorithm/NLP训练营笔记/图片/7596032B-41A9-40DA-8B17-CE4CCA5B8038.png"
display(Image(img_path3))

# %%
import jieba
seg_list_from_jieba = jieba.cut("NLP技术用于推理机构建的探索",cut_all=False)
'/'.join(seg_list_from_jieba)
# Out:
# 'NLP技术/用于/推理机/构建/的/探索'

# %%
jieba.add_word('NLP技术',1)
seg_list_from_jieba = jieba.cut("NLP技术用于推理机构建的探索",cut_all=False)
'/'.join(seg_list_from_jieba)
# Out:
# 'NLP技术/用于/推理机/构建/的/探索'

# %%
dict(enumerate('NLP技术/用于/推理机/构建/的/探索'.split('/')))
# Out:
# {0: 'NLP技术', 1: '用于', 2: '推理机', 3: '构建', 4: '的', 5: '探索'}

# %%
import sys
sys.path.append("../")
jieba.load_userdict("/Users/manmanzhang/Library/Mobile Documents/com~apple~CloudDocs/MyProject/InferenceSystem/src/I5_algorithm/NLP训练营笔记/图片/userdict.txt")
import jieba.posseg as pseg
