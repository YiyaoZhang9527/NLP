# %%
from IPython.display import HTML

# %%
HTML("https://www.cnblogs.com/ginvip/p/6439679.html")
# Out:
# <!DOCTYPE html>
# <html lang="zh-cn">
# <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <meta name="referrer" content="origin" />
#     <meta property="og:description" content="常见函数列表 文件操作 关于open的模式 w 写方式a 追加模式打开（从EOF开始，必要时创建新文件）r&#x2B; 以读写模式打开w&#x2B; 以读写模式打开a&#x2B; 以读写模式打开rb 以二进制读模式打开wb 以二进" />
#     <meta http-equiv="Cache-Control" content="no-transform" />
#     <meta http-equiv="Cache-Control" content="no-siteapp" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#     <title>python之OS模块详解 - 琴酒网络 - 博客园</title>
#     <link id="favicon" rel="shortcut icon" href="//common.cnblogs.com/favicon.ico?v=20200522" type="image/x-icon" />
#
#     <link rel="stylesheet" href="/css/blog-common.min.css?v=7Pwqzj5EBy4dBv4DJNI181rFKP8_OF0hT7jO3o8jAa0" />
#     <link id="MainCss" rel="stylesheet" href="/skins/lovegiveheart/bundle-lovegiveheart.min.css?v=AqT1EK144wxWiVmkpKx9KBe-fWsZg1Jwd6iFUglG2h8" />
# ...
